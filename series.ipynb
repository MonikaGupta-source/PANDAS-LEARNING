# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = ["monika","krishna","shikha"]
arr = np.array([10,20,30])
dict1 = {1:10,2:20,3:30}

# %%
pd.Series(my_list,index=labels)
# Out:
# a     monika
# b    krishna
# c     shikha
# dtype: object

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(dict1)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
