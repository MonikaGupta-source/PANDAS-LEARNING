# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ***PIVOT TABLES***

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    927     10   John  January      Q1
# 1  2023-01-02       B   West    668     77   Mary  January      Q1
# 2  2023-01-03       C  North    303     93    Bob  January      Q1
# 3  2023-01-04       D  South    710     73  Alice  January      Q1
# 4  2023-01-05       A   East    497     23   John  January      Q1
# 5  2023-01-06       B   West    354     57   Mary  January      Q1
# 6  2023-01-07       C  North    756     62    Bob  January      Q1
# 7  2023-01-08       D  South    750     32  Alice  January      Q1
# 8  2023-01-09       A   East    710     88   John  January      Q1
# 9  2023-01-10       B   West    642     31   Mary  January      Q1
# 10 2023-01-11       C  North    148     66    Bob  January      Q1
# 11 2023-01-12       D  South    117     60  Alice  January      Q1
# 12 2023-01-13       A   East    295     71   John  January      Q1
# 13 2023-01-14       B   West    330     89   Mary  January      Q1
# 14 2023-01-15       C  North    376     67    Bob  January      Q1
# 15 2023-01-16       D  South    165     82  Alice  January      Q1
# 16 2023-01-17       A   East    251     77   John  January      Q1
# 17 2023-01-18       B   West    324     58   Mary  January      Q1
# 18 2023-01-19       C  North    413     71    Bob  January      Q1
# 19 2023-01-20       D  South    217     29  Alice  January      Q1

# %%
#a pivot table is a powerful tool for reshaping and summarizing data. It lets you group, aggregate, and organize data in a spreadsheet-like format — similar to Excel pivot tables.

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product')
# Out:
# Product      A      B      C      D
# Region
# East     536.0    NaN    NaN    NaN
# North      NaN    NaN  399.2    NaN
# South      NaN    NaN    NaN  391.8
# West       NaN  463.6    NaN    NaN

# %% [markdown]
# ***index and coloumn be qualitative but values and aggregation always be quantitative ***

# %%
pivot2 = pd.pivot_table(df,values= ['Sales' , 'Units'] , index='Region',columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     536.0    NaN    NaN    NaN  53.8   NaN   NaN   NaN
# North      NaN    NaN  399.2    NaN   NaN   NaN  71.8   NaN
# South      NaN    NaN    NaN  391.8   NaN   NaN   NaN  55.2
# West       NaN  463.6    NaN    NaN   NaN  62.4   NaN   NaN

# %% [markdown]
# ***cross tables(for counting purpose)***

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
